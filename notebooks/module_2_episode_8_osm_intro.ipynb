# %% [markdown]
# # Introduction to OpenStreetMap (OSM)
# OpenStreetMap (OSM) is a collaborative, open-source mapping platform that provides structured geospatial data from around the world. Unlike traditional maps, OSM data can be downloaded, analyzed, and improved, making it a critical resource for urban mobility projects. This notebook introduces OSM and shows how to access its data using Python and the OSMnx library.

# %%
# Install OSMnx required library
# !pip install osmnx

# %%
import osmnx as ox
import matplotlib
matplotlib.use("Agg")
G = ox.graph_from_place("Lisbon, Portugal", network_type="drive")
ox.plot_graph(G)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 5
#       3 matplotlib.use("Agg")
#       4 G = ox.graph_from_place("Lisbon, Portugal", network_type="drive")
# ----> 5 ox.plot_graph(G)
#
# File ~/miniforge3/envs/geo-course/lib/python3.10/site-packages/osmnx/plot.py:243, in plot_graph(G, ax, figsize, bgcolor, node_color, node_size, node_alpha, node_edgecolor, node_zorder, edge_color, edge_linewidth, edge_alpha, bbox, show, close, save, filepath, dpi)
#     170 def plot_graph(  # noqa: PLR0913
#     171     G: nx.MultiGraph | nx.MultiDiGraph,
#     172     *,
#    (...)
#     189     dpi: int = 300,
#     190 ) -> tuple[Figure, Axes]:
#     191     """
#     192     Visualize a graph.
#     193
#    (...)
#     241         The resulting matplotlib figure and axes objects.
#     242     """
# --> 243     _verify_mpl()
# ...

# %% [markdown]
# You can also load different types of networks depending on your needs:
#
# ```python
# G = ox.graph_from_place('Lisbon, Portugal', network_type='bike')
# ox.plot_graph(G)
# ```
#
# Available types: `'walk'`, `'bike'`, `'drive'`, `'drive_service'`, `'all'`, `'all_private'`.

# %% [markdown]
# 📌 **Tip:** Try running this notebook in [Google Colab](https://colab.research.google.com) for an easy, setup-free experience.
#
# If you're unsure about what the code does, try pasting it into ChatGPT with a prompt like:
# `Explain this code in detail to someone with no programming background.`
